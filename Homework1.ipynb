nextdigital = 'http://www.nextdigital.com.hk/investor/'
nextdigita2 = 'http://www.nextdigital.com.hk/3c/'
nextdigitatw = 'http://www.nextdigital.com.tw/3c/'

# %%
b = 'apple'
print 'c' in b
print 'a' in b
print 'A' in b
# Out:
# False
# True
# False

# %%
print len(a)
# Out:
# 197

# %%
for url in a:
    if 'jpg' in url.lower():
        print url
# Out:
# http://twimg.edgesuite.net/appledaily/data/oct/eab1a5f30b22fb9673b2128c78396460.jpg
# http://twimg.edgesuite.net/appledaily/data/oct/0f0ac7889fa783173a0ba8219b288aa5.jpg
# http://twimg.edgesuite.net/appledaily/data/oct/5538ae7389bada229a80b131b2ee51fd.jpg
# http://twimg.edgesuite.net/appledaily/data/oct/6d4523b517ed8c75f601d04f648616ab.jpg
# http://twimg.edgesuite.net/appledaily/data/oct/086039fa04355fea37680a97a59d6392.jpg
# http://twimg.edgesuite.net/appledaily/data/oct/3edf2508df1aef539d47fbba604905e8.jpg
# http://twimg.edgesuite.net/appledaily/data/oct/d8947e2b2c5440f60d9affb0c1168044.jpg
# http://twimg.edgesuite.net/appledaily/data/oct/16cef19432443d1a00404f61f85b3137.jpg
# http://twimg.edgesuite.net/appledaily/data/oct/06d3e6cfd34121861d282fbcf82c1d17.jpg
# http://twimg.edgesuite.net/appledaily/data/oct/a7f496313df2e3dd080d8fe9b65f01ae.jpg

# %% [markdown]
# ## 第一題解答

# %%
cnt = 0
for url in a:
    if 'jpg' in url.lower():
        #cnt = cnt + 1 
        cnt +=1
print cnt
# Out:
# 10

# %%
ary = []
for url in a:
    if 'jpg' in url.lower():
        ary.append(url)
print ary
print len(ary)
#print cnt
# Out:
# ['http://twimg.edgesuite.net/appledaily/data/oct/eab1a5f30b22fb9673b2128c78396460.jpg', 'http://twimg.edgesuite.net/appledaily/data/oct/0f0ac7889fa783173a0ba8219b288aa5.jpg', 'http://twimg.edgesuite.net/appledaily/data/oct/5538ae7389bada229a80b131b2ee51fd.jpg', 'http://twimg.edgesuite.net/appledaily/data/oct/6d4523b517ed8c75f601d04f648616ab.jpg', 'http://twimg.edgesuite.net/appledaily/data/oct/086039fa04355fea37680a97a59d6392.jpg', 'http://twimg.edgesuite.net/appledaily/data/oct/3edf2508df1aef539d47fbba604905e8.jpg', 'http://twimg.edgesuite.net/appledaily/data/oct/d8947e2b2c5440f60d9affb0c1168044.jpg', 'http://twimg.edgesuite.net/appledaily/data/oct/16cef19432443d1a00404f61f85b3137.jpg', 'http://twimg.edgesuite.net/appledaily/data/oct/06d3e6cfd34121861d282fbcf82c1d17.jpg', 'http://twimg.edgesuite.net/appledaily/data/oct/a7f496313df2e3dd080d8fe9b65f01ae.jpg']
# 10

# %% [markdown]
# ## 第二題解答

# %%
ary = []
for url in a:
    if 'http' in url.lower():
        ary.append(url)
print ary
# Out:
# ['http://www.nextdigital.com.hk/investor/', 'http://www.applelive.com.tw/livechannel/', 'http://apple360.appledaily.com.tw/', 'http://sharpdaily.tw/', 'http://www.nextmag.com.tw', 'http://www.eat-travel.com.tw/', 'http://www.tomonews.com/', 'https://www.youtube.com/user/twappledaily/', 'http://www.twnextdigital.com/', 'http://www.nextdigital.com.hk/', 'http://www.nextdigital.com.hk/investor/', 'http://www.nextdigital.com.hk/investor/', 'http://www.appledaily.com.tw/complainevent', 'http://goo.gl/FcdlZ8', 'http://goo.gl/5BS0vR', 'http://www.appledaily.com.tw/column/index/265', 'http://goo.gl/aa8GyG', 'http://goo.gl/uilrxX', 'http://goo.gl/hlOhaZ', 'http://www.appledaily.com.tw/column/index/115/', 'http://goo.gl/Gh4hIC', 'http://goo.gl/8eeapZ', 'http://goo.gl/SgX2df', 'http://www.appledaily.com.tw/realtimenews/article/life/20160525/869593/', 'http://www.nextdigital.com.hk/investor/', 'http://www.applelive.com.tw/livechannel/', 'http://apple360.appledaily.com.tw/', 'http://sharpdaily.tw
# ...

# %%
c = 'http://www.nextdigital.com.hk/investor/'
print c.split('/')
print type(c.split('/'))
li  = c.split('/')
print li[2]


print c.split('/')[2]
# Out:
# ['http:', '', 'www.nextdigital.com.hk', 'investor', '']
# <type 'list'>
# www.nextdigital.com.hk
# www.nextdigital.com.hk

# %% [markdown]
# ## 第三題解答

# %%
#set
s = set()
for url in a:
    if 'http' in url.lower():
        domain = url.split('/')[2]
        if not 'appledaily.com.tw' in domain: 
            s.add(domain)
print s
# Out:
# set(['goo.gl', 'www.applelive.com.tw', 'www.facebook.com', 'www.eat-travel.com.tw', 'www.104.com.tw', 'twimg.edgesuite.net', 'www.youtube.com', 'www.tomonews.com', 'b.scorecardresearch.com', 'www.nextmag.com.tw', 'www.twnextdigital.com', 'sharpdaily.tw', 'www.nextdigital.com.hk'])

# %%
# dic
dic = {}
for url in a:
    if 'http' in url.lower():
        domain = url.split('/')[2]
        if not 'appledaily.com.tw' in domain: 
            if domain not in dic:
                dic[domain] = 1
            else:
                dic[domain] = dic[domain] + 1
print dic
# Out:
# {'goo.gl': 8, 'www.applelive.com.tw': 2, 'www.facebook.com': 1, 'www.eat-travel.com.tw': 2, 'www.104.com.tw': 1, 'twimg.edgesuite.net': 32, 'www.youtube.com': 2, 'www.tomonews.com': 2, 'b.scorecardresearch.com': 1, 'www.nextmag.com.tw': 2, 'www.twnextdigital.com': 1, 'sharpdaily.tw': 2, 'www.nextdigital.com.hk': 5}

# %%
import operator
print dic.items()
swd = sorted(dic.items(), key=operator.itemgetter(1), reverse=True)
print swd
# Out:
# [('goo.gl', 8), ('www.applelive.com.tw', 2), ('www.facebook.com', 1), ('www.eat-travel.com.tw', 2), ('www.104.com.tw', 1), ('twimg.edgesuite.net', 32), ('www.youtube.com', 2), ('www.tomonews.com', 2), ('b.scorecardresearch.com', 1), ('www.nextmag.com.tw', 2), ('www.twnextdigital.com', 1), ('sharpdaily.tw', 2), ('www.nextdigital.com.hk', 5)]
# [('twimg.edgesuite.net', 32), ('goo.gl', 8), ('www.nextdigital.com.hk', 5), ('www.applelive.com.tw', 2), ('www.eat-travel.com.tw', 2), ('www.youtube.com', 2), ('www.tomonews.com', 2), ('www.nextmag.com.tw', 2), ('sharpdaily.tw', 2), ('www.facebook.com', 1), ('www.104.com.tw', 1), ('b.scorecardresearch.com', 1), ('www.twnextdigital.com', 1)]

# %%
# Counter  in collections
from collections import Counter
c = Counter()
for url in a:
    if 'http' in url.lower():
        domain = url.split('/')[2]
        if not 'appledaily.com.tw' in domain: 
            c[domain] +=1
print c
print c.most_common(3)
# Out:
# Counter({'twimg.edgesuite.net': 32, 'goo.gl': 8, 'www.nextdigital.com.hk': 5, 'www.applelive.com.tw': 2, 'www.eat-travel.com.tw': 2, 'www.youtube.com': 2, 'www.tomonews.com': 2, 'www.nextmag.com.tw': 2, 'sharpdaily.tw': 2, 'www.facebook.com': 1, 'www.104.com.tw': 1, 'b.scorecardresearch.com': 1, 'www.twnextdigital.com': 1})
# [('twimg.edgesuite.net', 32), ('goo.gl', 8), ('www.nextdigital.com.hk', 5)]
